# %%
x=5
type(x)
# Out:
# int

# %%
y=3
x+y
# Out:
# 8

# %%
x%y
# Out:
# 2

# %%
x//y
# Out:
# 1

# %%
x/y
# Out:
# 1.6666666666666667

# %%
x==y
# Out:
# False

# %%
y=5

# %%
x==y
# Out:
# True

# %%
a=True
b=False
print(a and b)
# Out:
# False

# %%
print(a or b)
# Out:
# True

# %%
print(not(a and b))
# Out:
# True

# %%
text='I\'m a string'
print(text)
# Out:
# I'm a string

# %%
print('Myanmar '*3)
# Out:
# Myanmar Myanmar Myanmar
