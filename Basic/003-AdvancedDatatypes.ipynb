# %% [markdown]
# ## Lists

# %%
basket=['cooking oil', 'milk', 'apple', 'banana', 'orange']
basket[0]
# Out:
# 'cooking oil'

# %%
type(basket)
# Out:
# list

# %%
basket[-1]
# Out:
# 'orange'

# %%
basket[0:2]
# Out:
# ['cooking oil', 'milk']

# %%
'apple' in basket
# Out:
# True

# %%
'juice' in basket
# Out:
# False

# %%
len(basket)
# Out:
# 5

# %%
max(basket)
# Out:
# 'orange'

# %%
min(basket)
# Out:
# 'apple'

# %%
sorted(basket)
# Out:
# ['apple', 'banana', 'cooking oil', 'milk', 'orange']

# %%
'-'.join(basket)
# Out:
# 'cooking oil-milk-apple-banana-orange'

# %%
basket.append('salt')
basket
# Out:
# ['cooking oil',
#  'milk',
#  'apple',
#  'banana',
#  'orange',
#  'salt',
#  'salt',
#  'salt',
#  'salt',
#  'salt']

# %%
basket.remove('salt')
basket
# Out:
# ['cooking oil', 'milk', 'apple', 'banana', 'orange', 'salt']

# %%
basket.insert(5,'rice')
basket
# Out:
# ['cooking oil', 'milk', 'apple', 'banana', 'orange', 'rice', 'salt']

# %%
basket.pop()
basket
# Out:
# ['cooking oil', 'milk', 'apple', 'banana', 'orange']

# %%
basket.pop(0)
basket
# Out:
# ['milk', 'apple', 'banana', 'orange']

# %%
listA=[1,2,3]
listB=[4,5,6]
listC=listA + listB
listC
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
listC.clear()
listC
# Out:
# []

# %% [markdown]
# ## Tuples

# %%
garage = ('Volvo', 'Honda', 'Audi', 'BMW')
garage
# Out:
# ('Volvo', 'Honda', 'Audi', 'BMW')

# %%
type(garage)
# Out:
# tuple

# %%
garage[0]
# Out:
# 'Volvo'

# %%
garage[-1]
# Out:
# 'BMW'

# %%
car1, car2, car3, car4 = garage

# %%
print(car1 + ' '+ car4)
# Out:
# Volvo BMW

# %%
sorted(garage)
garage
# Out:
# ('Volvo', 'Honda', 'Audi', 'BMW')

# %%
garage.append('Mercedes')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 garage.append('Mercedes')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
garage_list = list(garage)
garage_list
# Out:
# ['Volvo', 'Honda', 'Audi', 'BMW']

# %%
sorted(garage_list)
# Out:
# ['Audi', 'BMW', 'Honda', 'Volvo']

# %%
garage_tuple = tuple(garage_list)
garage_tuple
# Out:
# ('Volvo', 'Honda', 'Audi', 'BMW')

# %% [markdown]
# ## Sets

# %%
num = {1,2,1,3,4,5}
num
# Out:
# {1, 2, 3, 4, 5}

# %%
num[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 num[0]
#
# TypeError: 'set' object is not subscriptable

# %%
1 in num
# Out:
# True

# %%
num.add(6)
num
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
num.update([7,8])
num
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
num.remove(1)
num
# Out:
# {2, 3, 4, 5, 6, 7, 8}

# %%
pop_item = num.pop()
print(pop_item)
num
# Out:
# 2
# {3, 4, 5, 6, 7, 8}

# %%
num.clear()
num
# Out:
# set()

# %%
del num
num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 2
#       1 del num
# ----> 2 num
#
# NameError: name 'num' is not defined

# %%
male = {'Daddy', 'Son', 'Child'}
female = {'Mommy', 'Daughter', 'Child'}
family = male.union(female)
family
# Out:
# {'Child', 'Daddy', 'Daughter', 'Mommy', 'Son'}

# %%
common_item = male.intersection(female)
common_item
# Out:
# {'Child'}

# %%
copy = family.copy()
copy
# Out:
# {'Child', 'Daddy', 'Daughter', 'Mommy', 'Son'}

# %% [markdown]
# ## Dictionaries

# %%
months = {'Jan':31, 'Feb':28, 'Mar':31, 'Apr':30}
months
# Out:
# {'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30}

# %%
months['Feb']
# Out:
# 28

# %%
garbage = {1:'One', 'Two': 2}
garbage['Two']
# Out:
# 2

# %%
garbage['One']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 garbage['One']
#
# KeyError: 'One'

# %%
'Jan' in months
# Out:
# True

# %%
31 in months
# Out:
# False

# %%
months.get('Jan')
# Out:
# 31

# %%
copy = months.copy()
copy
# Out:
# {'Jan': 31, 'Feb': 28, 'Mar': 31, 'Apr': 30}

# %%
months['Feb'] = 29
months
# Out:
# {'Jan': 31, 'Feb': 29, 'Mar': 31, 'Apr': 30}

# %%
months.pop('Jan')
months
# Out:
# {'Feb': 29, 'Mar': 31, 'Apr': 30}

# %%
months.clear()
months
# Out:
# {}
