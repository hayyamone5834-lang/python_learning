# %%
student = 'matric pass'
if student == 'matric pass':
    next_course = 'Degree'
print(next_course)
# Out:
# Degree

# %%
student = 'matric failed'
if student == 'matric pass':
    next_course = 'Degree'
else:
    next_course = 'Other'
print(next_course)
# Out:
# Other

# %%
student = 'Degree pass'
if student == 'matric pass':
    next_course = 'Degree'
elif student == 'Degree pass':
    next_course = 'Master'
elif student == 'Master pass':
    next_course = 'Phd'
else:
    next_course = 'Other'
print(next_course)
# Out:
# Master

# %%
mark = 65
rank = 'None'
if mark > 59 and mark < 80:
    rank = 'Credit'
print(rank)
# Out:
# Credit

# %%
subjects = ['English', 'Maths', 'Science', 'Social']
for subject in subjects:
    print(subject)
# Out:
# English
# Maths
# Science
# Social

# %%
for i in range(5):
    print('Data')
# Out:
# Data
# Data
# Data
# Data
# Data

# %%
for i in range(len(subjects)):
    print(subjects[i])
# Out:
# English
# Maths
# Science
# Social

# %%
cap_sub = []
for sub in subjects:
    cap_sub.append(sub.upper())
print(cap_sub)
# Out:
# ['ENGLISH', 'MATHS', 'SCIENCE', 'SOCIAL']

# %%
score = 0
while score < 80:
    print(score)
    score += 10
print('Not less than 80')
print(score)
# Out:
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# Not less than 80
# 80

# %%
score = 0
while score < 80:
    score += 10
    if score > 40:
        break
    print(score)
print('Exit before 80')
# Out:
# 10
# 20
# 30
# 40
# Exit before 80

# %%
score = 0
while score < 30:
    score += 3
    if score%2 != 0:
        print(score)
        continue
print('Loop end')
# Out:
# 3
# 9
# 15
# 21
# 27
# Loop end
