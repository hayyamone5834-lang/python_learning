# %%
import pandas as pd
df = pd.read_csv('regression-one.csv')
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.rename(columns = {'Life expectancy': 'life-expect'}, inplace=True)
df.head()
# Out:
#        Country  Year      Status  life-expect  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing         65.0            263.0             62
# 1  Afghanistan  2014  Developing         59.9            271.0             64
# 2  Afghanistan  2013  Developing         59.9            268.0             66
# 3  Afghanistan  2012  Developing         59.5            272.0             69
# 4  Afghanistan  2011  Developing         59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles  ...  Polio  \
# 0     0.01               71.279624         65.0     1154  ...    6.0
# 1     0.01               73.523582         62.0      492  ...   58.0
# 2     0.01               73.219243         64.0      430  ...   62.0
# 3     0.01               78.184215         67.0     2787  ...   67.0
# 4     0.01                7.097109         68.0     3013  ...   68.0
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                                      Year  life-expect  Adult Mortality  \
# Year                             1.000000     0.170033        -0.079052
# life-expect                      0.170033     1.000000        -0.696359
# Adult Mortality                 -0.079052    -0.696359         1.000000
# infant deaths                   -0.037415    -0.196557         0.078756
# Alcohol                         -0.052990     0.404877        -0.195848
# percentage expenditure           0.031400     0.381864        -0.242860
# Hepatitis B                      0.104333     0.256762        -0.162476
# Measles                         -0.082493    -0.157586         0.031176
# BMI                              0.108974     0.567694        -0.387017
# under-five deaths               -0.042937    -0.222529         0.094146
# Polio                            0.094158     0.465556        -0.274823
# Total expenditure                0.090740     0.218086        -0.115281
# ...

# %%
df[['life-expect', 'GDP', 'Alcohol', 'BMI', 'Schooling']].corr()
# Out:
#              life-expect       GDP   Alcohol       BMI  Schooling
# life-expect     1.000000  0.461455  0.404877  0.567694   0.751975
# GDP             0.461455  1.000000  0.354712  0.301557   0.448273
# Alcohol         0.404877  0.354712  1.000000  0.330408   0.547378
# BMI             0.567694  0.301557  0.330408  1.000000   0.546961
# Schooling       0.751975  0.448273  0.547378  0.546961   1.000000

# %%
df[df.isnull().any(axis=1)]
# Out:
#        Country  Year      Status  life-expect  Adult Mortality  infant deaths  \
# 32     Algeria  2015  Developing         75.6             19.0             21
# 44     Algeria  2003  Developing         71.7            146.0             20
# 45     Algeria  2002  Developing         71.6            145.0             20
# 46     Algeria  2001  Developing         71.4            145.0             20
# 47     Algeria  2000  Developing         71.3            145.0             21
# ...        ...   ...         ...          ...              ...            ...
# 2918    Zambia  2003  Developing         46.4             64.0             39
# 2919    Zambia  2002  Developing         45.5             69.0             41
# 2920    Zambia  2001  Developing         44.6            611.0             43
# 2921    Zambia  2000  Developing         43.8            614.0             44
# 2922  Zimbabwe  2015  Developing         67.0            336.0             22
#
# ...

# %%
df = df.dropna()
df.shape
# Out:
# (1649, 22)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, life-expect, Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles, BMI, under-five deaths, Polio, Total expenditure, Diphtheria, HIV/AIDS, GDP, Population, thinness 1-19 years, thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %%
import matplotlib.pyplot as plt

plt.scatter(df['Schooling'], df['life-expect'], marker='o')
plt.show()

# %%
X = df[['Schooling']]
Y = df['life-expect']
X.head()
# Out:
#    Schooling
# 0       10.1
# 1       10.0
# 2        9.9
# 3        9.8
# 4        9.5

# %%
Y.head()
# Out:
# 0    65.0
# 1    59.9
# 2    59.9
# 3    59.5
# 4    59.2
# Name: life-expect, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
slr = LinearRegression()
slr
# Out:
# LinearRegression()

# %%
slr.fit(X,Y)
# Out:
# LinearRegression()

# %%
Yhat = slr.predict(X)
Yhat[0:5]
# Out:
# array([64.6771856 , 64.44820695, 64.2192283 , 63.99024965, 63.30331369])

# %%
df.head()
# Out:
#        Country  Year      Status  life-expect  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing         65.0            263.0             62
# 1  Afghanistan  2014  Developing         59.9            271.0             64
# 2  Afghanistan  2013  Developing         59.9            268.0             66
# 3  Afghanistan  2012  Developing         59.5            272.0             69
# 4  Afghanistan  2011  Developing         59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles  ...  Polio  \
# 0     0.01               71.279624         65.0     1154  ...    6.0
# 1     0.01               73.523582         62.0      492  ...   58.0
# 2     0.01               73.219243         64.0      430  ...   62.0
# 3     0.01               78.184215         67.0     2787  ...   67.0
# 4     0.01                7.097109         68.0     3013  ...   68.0
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df.insert(4, 'predict-life-expect', Yhat, True)
df.head()
# Out:
#        Country  Year      Status  life-expect  predict-life-expect  \
# 0  Afghanistan  2015  Developing         65.0            64.677186
# 1  Afghanistan  2014  Developing         59.9            64.448207
# 2  Afghanistan  2013  Developing         59.9            64.219228
# 3  Afghanistan  2012  Developing         59.5            63.990250
# 4  Afghanistan  2011  Developing         59.2            63.303314
#
#    Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0            263.0             62     0.01               71.279624
# 1            271.0             64     0.01               73.523582
# 2            268.0             66     0.01               73.219243
# 3            272.0             69     0.01               78.184215
# 4            275.0             71     0.01                7.097109
#
#    Hepatitis B  ...  Polio  Total expenditure  Diphtheria  HIV/AIDS  \
# 0         65.0  ...    6.0               8.16        65.0       0.1
# ...

# %%
df['Schooling'].max()
# Out:
# 20.7

# %%
df['Schooling'].min()
# Out:
# 4.2

# %%
slr.predict([[15]])
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([75.89713955])

# %%
slr.predict([[5]])
# Out:
# C:\Users\Acer\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([52.99927435])

# %% [markdown]
# ### y = mx + b

# %%
slr.coef_
# Out:
# array([2.28978652])

# %%
slr.intercept_
# Out:
# np.float64(41.5503417453634)

# %%
y = (2.28978652*5) + 41.5503417453634
y
# Out:
# 52.999274345363396

# %%
import seaborn as sns

sns.regplot(x = df['Schooling'], y = df['life-expect'])
plt.show()
